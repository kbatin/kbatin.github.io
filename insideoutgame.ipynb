# %% [markdown]
# This game is based on the movie Inside Out (2015). It teaches its viewers the lesson in adapting to change, acknowledging and processing one’s emotion, and understanding that not all memories are pure happiness.
#
# Have fun playing this game!

# %%
# 12/3 5:17 i put my intro here 
# 11/30 6:30 third copy of the game. please 
# Please don't mind some comments. Just putting everything here. Thanks.

#import random
import random

import time
# time sleep in stage3

# insideout intro

def insideout():
    print(f"""
Do you ever look at someone and wonder, "What is going on inside their head?" - Joy

{'😂😥😡😱🤢' * 10}

The story begins in the mind of an 11-year-old girl named Riley,
who grew up in Minnesota and moved to San Francisco with her family.
While adapting to a new environment, Riley and her emotions struggles to adjust.

Her emotions—Joy, Sadness, Anger, Fear, and Disgust—live in Headquarters, the
control center of her mind where the 5 emotions live and work,
monitoring her experiences and guiding her along the way. 

One day, Joy and Sadness get accidentally sucked up and transported away
from Headquarters to Long Term Memory along with Riley’s core memories.
This leaves Fear, Anger, and Disgust in charge of Riley’s thoughts, feelings,
and actions.

In Long Term Memory, there are 5 bridges that connect to different
Islands of Personality–Goofball, Honesty, Hockey, Friendship, and Family.
These are powered by Riley’s core memory. Since the core memories are
with Joy, all islands are down.


The goal is for Joy and Sadness to go back to Headquarters, so Riley
can be normal again.


Lots of fun stuff! ( ⸝⸝´꒳`⸝⸝)


{'😂😥😡😱🤢' * 10}


Are you ready? Of course you're ready!!!

\n""") 
    
    #used emoji text to show emotions (1)
    #lots of fun stuff (1)
    
    input(prompt ='Press any key to start! ᕙ(  •̀ ᗜ •́  )ᕗ \n') #strong emoji

    #used emoji text to show emotions (2)
    
#what's happening in longterm memory
    print(f"""
In Long Term Memory, Joy and Sadness were thinking which bridge would be
the easiest to cross going back.

They chose to cross throgh Goofball Island.
\n""")

    #start of questions
    #stage 1
#start of question 1
    stage1()
    
def stage1():
    print(f"""📌 Headquarters
    
While eating dinner, Mom mentioned the Hockey tryout for tomorrow.
\n""")
    print(f"""
As Anger, Disgust, or Fear, what will be Joy’s answer to 
“How was your day?”

a. School was great alright?!?! ┬─┬ノ(ಠ_ಠノ)
b. Oh, fantastic, I guess. ⊙˛̼⊙
c. I don’t know. ヽ( ͡ಠ ʖ̯ ͡ಠ)ﾉ

Enter the letter of your choice.
\n""")
        #used emoji text to show emotions (3)
        
    q1choice = input(prompt = "🧠 ")
    
#casefolding the input
    q1choice = q1choice.casefold()
    
     #conditions with letters and possible answers

# LETTER A.  this is from question1
    if 'great' in q1choice.lower().strip() or q1choice.strip() == 'a' or 'alright' in q1choice.lower().strip() or q1choice == '?!?!' or 'school' in q1choice.lower().strip() or q1choice == 'a.' or q1choice == 'a. ' or q1choice == 'a .':
        # just to be sure
        print("Oooohh, that was mean.")
        #go to question 1_3
    
        #start of question 1_3
        print(f"""
Dad: Riley, I don’t like this new attitude.
What will be Joy’s answer?

a. “Just shut up!” (੭ꐦ •̀Д•́ )੭*
b. “I’m sorry, dad.” (ノ _ <,, )
c. Panic then cry (｡•́︿•̀｡)

Enter the letter of your choice.
\n""")

            #used emoji text to show emotions (4)


        q1_3choice = input(prompt = "🧠 ")

            #casefolding the input
        q1_3choice = q1_3choice.casefold()

# LETTER A this is from question1_3            
    #conditions with letters only
        if 'shut' in q1_3choice.lower().strip() or q1_3choice.strip() == 'a' or '(੭ꐦ •̀Д•́ )੭*' in q1_3choice.lower().strip() or q1_3choice == 'a.':
            print("Oh no! The Goofball Island collapsed!")
            print("Goofball Island represents her playful and silly side.")
            print("Now, Joy and Sadness ran back to the Long Term Memory.")

            #go to stage3()
            stage3()
# 11/29 10:45 I was thinking of prompting the OH NO

# 11/29 10:32 PM not sure what room title yet. LONGTERM MEMORY

# LETTER B this is from question1_3
        elif 'sorry' in q1_3choice.lower().strip() or q1_3choice.strip() == 'b' or q1_3choice.strip() == 'b.':
            print("💨 💨 💨")
            print("Joy and Sadness got a speed booster and reached Goofball Island! Yaaayyy!")

            # this is leading to the second stage. yay!	

            stage2()
# no question for stage2() yet

# there is now 12/1 8:30 pm

# LETTER C this is from question1_3
        elif 'panic' in q1_3choice.lower().strip() or q1_3choice.strip() == 'c' or q1_3choice.strip() == 'c.' or 'cry' in q1_3choice.lower().strip():
            print("Don’t cry, Joy and Sadness are halfway to the Goofball Island!")

            #go to question1_5

            #start of question 1_5
            print("Along the way, they encountered the Goofy Monster and challenged them for a tickle battle.")
            print("Guess a number between 1 and 5 to uncover a corresponding body part to tickle.")

            while True:
                random_number = random.randint(1, 5)
    
                try:
                    q1_5choice = int(input("Guess a number between 1 and 5: "))
        
        # trying to control
                    if q1_5choice < 1 or q1_5choice > 5:
                        print("Please enter a number between 1 and 5.")
                        continue
        
                    body_parts = {
                        1: "elbow",
                        2: "foot",
                        3: "belly",
                        4: "cheeks",
                        5: "palm"
                    }
        
                    chosen_body_part = body_parts.get(q1_5choice, "Invalid choice")
                    correct_body_part = body_parts.get(random_number)
        
                    if chosen_body_part != "Invalid choice":
                        print(f"You picked: {chosen_body_part}")
                        print(f"The Goofy Monster's ticklish spot is: {correct_body_part}")
        # let this work
                        if q1_5choice == random_number:
                            print("HAHAHAHA! Hooraaaayy!")
                            print("Tickle Monster burst in laughter!")
                            print("Joy and Sadness can now safely pass through the bridge!")
                            print("(づ˶•༝•˶)づ ヾ( ˃ᴗ˂ )◞ *✰")
            
                            stage2()
                
                        else:
                            print("Oh no! Tickle Monster didn't even laughed.")
                            print("He threw Joy and Sadness to back to Long Term Memory.")
                            print("( ´･･)ﾉ(._.`)")
                        
                            fail()
                            
                    else:
                        print("Really? (੭ ˊ^ˋ)੭ Pick from 1, 2, 3, 4, or 5.")
                except:
                        print("Pick from 1, 2, 3, 4, or 5.")

                        #used emoji text to show emotions (7)

        else:
            print("Really? <( ⸝⸝•̀ - •́⸝⸝)> Please follow the instructions.")
            input('<Press any key to continue>\n')

                        #used emoji text to show emotions (17)
                
            stage1()
            
# end of question 1_5
# end of question 1_3       

# 11/30 10:01 WORKING       
 
# LETTER B AND C this is from question1
    elif 'fantastic' in q1choice.lower().strip() or q1choice.strip() == 'b' or q1choice.strip() == 'c':
        print("Oooohh, that's not Joy, but at least you tried")

        #go to question 1_2
        
        #start of question 1_2
        print(f"""
Dad asked: Is there something wrong?
What will be Joy’s answer?

a. Nothing’s wrong. This day is just tiring, Dad. (¬_¬)
b. Nothing ( ,,,’･~･’,,)
c. Stop asking things! (˚ ˃̣̣⌓˂̣̣ )

Enter the letter of your choice.
\n""")

            #used emoji text to show emotions (5)
# 12/3 8:18 ended here
        
        q1_2choice = input(prompt = "🧠 ")

        #casefolding the input
        q1_2choice = q1_2choice.casefold()

# LETTER A and B this is from question1_2
        #conditions with letters only
        if 'nothing' in q1_2choice.lower().strip() or q1_2choice == 'a' or q1_2choice == 'b':
            print("I see your effort, keep trying.")
            
            #go to question1_4()
            
            #start of question 1_4
            print(f"""
Dad: Everything will be alright, Riley.
What will be Joy’s answer?

a. “Yeah, right.” *rolls eyes* (¬_ ´¬ )
b. “I hope so, Dad.” ( ´･_･`)
c. “No!” ( °□°) ︵ ┻━┻

Enter the letter of your choice.
\n""")

            #used emoji text to show emotions (6)


            q1_4choice = input(prompt = "🧠 ")

            #casefolding the input
            q1_4choice = q1_4choice.casefold()

# LETTER A and c this is from question1_4
        #conditions with letters only
            if 'yeah' in q1_4choice.lower().strip() or q1_4choice == 'a' or q1_4choice == 'c' or 'no' in q1_4choice.lower().strip():
                print("Oh no! The Goofball Island collapsed!")
                print("Goofball Island represents her playful and silly side.")
                print("Now, Joy and Sadness ran back to the Long Term Memory.")
# 11/29 10:45 I was thinking of prompting the OH NO

# 11/29 10:32 PM not sure what room title yet. LONGTERM MEMORY
                
                # go to stage3()
                stage3()

# 11/30 10:13 WORKING

# LETTER B this is from question1_4
            elif 'hope' in q1_4choice.lower().strip() or q1_4choice =='b':
                print("💨 💨 💨")
                print("Joy and Sadness got a speed booster and reached Goofball Island! Yaaayyy!")

                #go to stage2()
                stage2()

# ELSE q1_4
            else:
                print("Really? <( ⸝⸝•̀ - •́⸝⸝)> Please follow the instructions.")
                input('<Press any key to continue>\n')
            # 11/30 8:38 WILL THINK OF OTHER INPUT 
            # 12/3 can't think of any, helpppp
                
                stage1()

# end of question 1_4

# LETTER C this is from question1_2
        elif 'stop' in q1_2choice.lower().strip() or q1_2choice == 'c':
            print("Oh no! The Goofball Island collapsed!")
            print("Goofball Island represents her playful and silly side.")
            print("Now, Joy and Sadness ran back to the Long Term Memory.")

# 11/29 not sure which room would this lead yet. LONGTERM MEMORY
            #go to stage3()
            stage3()

# ELSE q1_2
        else:
            print("Really? <( ⸝⸝•̀ - •́⸝⸝)> Please follow the instructions.")
            input('<Press any key to continue>\n')
            
            stage1()

# end of question 1_2

#ELSE q1
    else:
        print("Really? <( ⸝⸝•̀ - •́⸝⸝)> Please follow the instructions.")
        input('<Press any key to continue>\n')
        
        stage1()

# end of question1   

# 11/30 10:35 WORKING
# 12/1 1:09 am WORKING will continue tomorrow


# 12/1 8:31 stage 2 huhu


def stage2():
    print(f"""
For Joy and Sadness to enter the Headquarters, they need to do sorting puzzle. 
Since Sadness helps Riley to recognize and process her emotions,
Sadness volunteered to do this challenge.

Help Sadness to categorize the memories listed based on the corresponding emotion.
Make sure to provide five accurate responses to enter the Headquarters.


Lots of fun stuff! ( ⸝⸝´꒳`⸝⸝)


Here are the emotions you can choose from: Joy, Sadness, Anger, Fear, and Disgust

Note that only one emotion per item is needed. You can do this!

\n""")

            # used emoji text to show emotions (8)
    

    question2 = [
    ("Riley's feelings on moving to San Francisco. 🧠 ", ["sadness", "fear", "scared", "anger", "angry", "disgust", "angry", "sad"]),
    ("Riley's friendship with Bing Bong (her imaginary friend when she was younger) 🧠 ", ["joy", "happy"]),
    ("A funny commercial 🧠 ", ["joy", "happy"]),
    ("Her first Hockey tryouts 🧠 ", ["fear", "sadness", "sad", "scared"]),
    ("Baby Riley's first encounter of Broccoli where she recognized an unfamiliar scent. 🧠 ", ["disgust"])
]

    # added happy, sad, scared, and angry just in case :)
    
    correct_answers = 0
    incorrect_answer = 1

    for question, possible_answers in question2:
        q2_1choice = input(question + " ")
    
    # Check if the user's answer partially matches any correct answer
        if any(answer.lower() in q2_1choice.lower() for answer in possible_answers):
            correct_answers += 1
              
        else:
            print("Oops! It's not the correct answer ¯\_(ツ)_/¯")
            print("Joy and Sadness needs to find other ways to enter the Headquarters")
                      
            # used emoji text to show emotions (9)

            #go to question2_2
            print(f"""
What should Joy and Sadness do now?
a. Jump on a trampoline!
b. Make Sadness cry and use her tears like a Flyboard to reach the top of Headquarters.

Enter the letter of your choice.
\n""")
        
            q2_2choice = input(prompt = "🧠 ")

            #casefolding the input
            q2_2choice = q2_2choice.casefold()
     
            #conditions with letters only
            if q2_2choice == 'a':
                
        # did not add other possible answers, because the user might write, cry on the trampoline
                
                #go to question2_3
            
                #start of question2_3
                print(f"""
What does Joy needs to do for them to reach the top?
a. Let Sadness lookdown to see how high they are. (｡･･｡)
b. Let Joy sing How Far I'll Go (song from Moana movie) ♪♪(oᐛ)o～♪♪

Enter the letter of your choice.
\n""")
                 #used emoji text to show emotions (10)


                q2_3choice = input(prompt = "🧠 ")

                #casefolding the input
                q2_3choice = q2_3choice.casefold()


        #conditions with letters only
                if q2_3choice == 'a':
                    print("Sadness worried too much and got distracted mid-air.")
                    print("This made them fall back to the Goofball Island. (•ᴖ•｡)")
            
                elif q2_3choice == 'b':
                    print("YAAAAYYY! Joy and Sadness are now back to the Headquarters!")
                    print("(ㅅ´ ˘ `)⸜(｡˃ ᵕ ˂ )⸝")

                 #used emoji text to show emotions (11)

            # didn't add, 'sadness', 'lookdown', 'joy', 'sing' because user might type, let sadness sing.
                
                    win()
        
                else:
                    print("Really? <( ⸝⸝•̀ - •́⸝⸝)> Please follow the instructions.")
                    input('<Press any key to continue>\n')
                    
                    stage2()
                

# end of question2_3

            elif q2_2choice == 'b':
                print("That was a smart move!")
                print("Joy and Sadness are now back to the Headquarters!")
                print("(ㅅ´ ˘ `)⸜(｡˃ ᵕ ˂ )⸝")
            
              # did not add other possible answers, because the user might write, cry on the trampoline
                
                 #used emoji text to show emotions (12)
                win()

            else:
                print("Really? <( ⸝⸝•̀ - •́⸝⸝)> Please follow the instructions.")
                input('<Press any key to continue>\n')  
                stage2()
                
            break        
# break from loop

# end of question2_3

    if correct_answers == 5:
        print("You got everything correct!")
        print("Joy and Sadness are now back to the Headquarters!")
        
        win()
# end of question 2_1
             

# 12/2 2:12 WORKING
    
    
def win():
    print(f"""

٩(ˊᗜˋ*)و Yaaayy! Thanks for helping Riley's emotions in their mini adventure!

Hope you had fun!

😂 😥 😡 😱 🤢
\n""")
    input("Press any key to try again ༼ つ ◕_◕ ༽つ")

    insideout()
# end of win    

                 #used emoji text to show emotions (13)
    
# 12/2 1:11 FINALLY WORKED


# 12/2 3:14

def fail():
    print(f"""

(っ- ‸ - ς) Oh no, Joy and Sadness are stuck in the Memory Dump ( ｡ • ᴖ • ｡)

What will happen to Riley without Joy and Sadness? ૮₍´˶• . • ⑅ ₎ა
\n""")
    input("Press any key to try again ༼ つ ◕_◕ ༽つ")
    
    insideout()

                 #used emoji text to show emotions (14)




def stage3():
    print(f"""
They are thinking of ways to go back to the Headquarters.

Along the way, they met Bing Bong, Riley's imaginary friend.
Bing Bong has been informative on what's happening in the Long Term Memory. 

Bing Bong suggested different ways to go back to the Headquarters.
First, they need to walked through the Imagination Island.

Lots of fun stuff! ( ⸝⸝´꒳`⸝⸝)

Do you want to enter the Imagination Island?
\n""")
    
        #used emoji text to show emotions (15)    
        
# stage 2 question2_1_1        
    question3_1choice = input(prompt = "Yes or No? 🧠 ")
    
# casefolding the input
    question3_1choice = question3_1choice.casefold()
    
     # conditions
    if 'yes' in question3_1choice.lower().strip() or question3_1choice == 'y':
        print("Help Joy, Sadness, and Bing Bong to cross the island through using your imagination.")
        print("Unleash your creativity!") 
        print("Doubting yourself? Don't worry, there will be a guide along the way. You can do this!")
    # go to question3_1_1

    # start of question3_1_1
        color3_1_1 = input(prompt = "What's your favorite color? (orange) 🧠 ").lower()

        if color3_1_1 == color3_1_1:
            print(f"Bing Bong, Joy, and Sadness, just went inside the {color3_1_1} room.")
    # go to question3_1_2
    
    # start of question3_1_2            
            animal3_1_2 = input(prompt = "What's your favorite animal? (dog) 🧠 ").lower()
                           
    # go to question3_1_3
    
    # start of question3_1_3
            comfort3_1_3 = input(prompt = "What is your comfort food? (ice cream) 🧠 ").lower()
               
            if animal3_1_2 == animal3_1_2 and comfort3_1_3 == comfort3_1_3:
                print(f"The {animal3_1_2} manager greeted them with {comfort3_1_3}.")
    # go to question3_1_4
    
    # start of question3_1_4              
                print("Who is your favorite singer/band?")
                singer3_1_4 = input(prompt = "I know you have a lot in mind, just pick one. 🧠 ").title()
                
     # start of question3_1_5              
                print("What's your favorite song?")
                song3_1_5 = input(prompt = "I know you have a lot in mind, just pick one. 🧠 ").title()               
                
     # start of question3_1_6              
                print("What's your favorite dessert?")
                dessert3_1_6 = input(prompt = "I know you have a lot in mind, just pick one. 🧠 ").lower()              
                
                if singer3_1_4 == singer3_1_4 and song3_1_5 and dessert3_1_6:
                    print(f"On the left side of the room, {singer3_1_4} is performing {song3_1_5} in a pool full of {dessert3_1_6}.")

    # start of question3_1_7
                    wings3_1_7 = input(prompt = "Yes or No: Do you want to have wings? 🧠 ")

                    wings3_1_7 = wings3_1_7.casefold()

                    if 'yes' in wings3_1_7.lower().strip() or wings3_1_7 == 'y':
                        print("What is your dream car?")
    # start of question3_1_8
                        car3_1_8 = input("If you have a lot, just pick one. 🧠 ").title()
                        
                        if car3_1_8 == car3_1_8:
                            print(f"On the right side of the room, there is a huge {car3_1_8} that has wings!")

    # start of question3_1_10
                            print("Do you want Joy and Sadness to use this car to reach the Headquarters?")

                            question3_1_10choice = input("Yes or No? 🧠 ")
                        
                            question3_1_10choice = question3_1_10choice.casefold()

                            if 'yes' in question3_1_10choice.lower().strip() or question3_1_10choice == 'y':
                                print("Great!")
                                print("Do you want sadness to drive the car?")

    # start of question3_1_11                            
#here
                                question3_1_11choice = input("Yes or No? 🧠 ")
                            
                                question3_1_11choice = question3_1_11choice.casefold()

                                if 'yes' in question3_1_11choice.lower().strip() or question3_1_11choice == 'y':
                                    print("Sweet! •ᴗ• They will be flying through a cotton candy clouds!")
                                    time.sleep(3)
                                    print("YAAAAYYY! Joy and Sadness are now back to the Headquarters!")
                                
                                    win()
                                
                                else:
                                    print("I see. That's fine. They will be flying through brocolli-like clouds 🥦")                    

    # start of question3_1_12                               
                                    print(f"""
Along the way, they encountered a Brocolli Monster 🥦.
Nooooo (｡>﹏<)
It was throwing small brocolli to their car.
Their car was covered with pieces of brocolli 🥦🥦🥦! In which direction should they go to?")
\n""")
                                
                                    question3_1_12 = input("Left or Right? 🧠 ")

                                    question3_1_11choice = question3_1_11choice.casefold()
                                
                                    if 'left' in question3_1_10choice.lower().strip() or question3_1_10choice == 'l':
                                        print("💨 💨 💨")
                                        time.sleep(2)
                                        print(f"""
They have now escaped the Brocolli Monster 🥦.
Woooohh! That was scary. Thanks for helping.
\n""")
                                        time.sleep(3)
                                        print("YAAAAYYY! Joy and Sadness are now back to the Headquarters!")
                                
                                        win()
                                    
                                    else:
                                        print("💨 💨 💨")
                                        time.sleep(1)
                                        print(f"""
🚨🚨🚨
Their car bumped into a big brocolli 🥦 and fell to the Memory Dump.
( ;´ - `;)
\n""")
                                    
                                        fail()
                                                         
                            else:
                                stage4()
    # start of question3_1_9                    
                    else:
                        print("What is your dream car?")
                        car3_1_9 = input("If you have a lot, just pick one. 🧠 ").title()
                        print(f"On the right side of the room, there is a huge {car3_1_9}!")
# here here

    # start of question3_1_13
                        print("Do you want Joy and Sadness to use this car to reach the Headquarters?")

                        question3_1_13choice = input("Yes or No? 🧠 ")
                        question3_1_13choice = question3_1_13choice.casefold()

                        if 'yes' in question3_1_13choice.lower().strip() or question3_1_13choice == 'y':

    # start of question3_1_14
                            print("Great!")
                            print("Do you want sadness to drive the car?")
                            
                            question3_1_14choice = input("Yes or No? 🧠 ")
                            question3_1_14choice = question3_1_14choice.casefold()

                            if 'yes' in question3_1_14choice.lower().strip() or question3_1_14choice == 'y':
                                print("Sweet! •ᴗ• They will be driving through a cotton candy road!")
                                time.sleep(3)
                                print("YAAAAYYY! Joy and Sadness are now back to the Headquarters!")
                                
                                win()
                                
                            else:
                                print("I see. That's fine. They will be driving through brocolli-like road 🥦")
    # start of question3_1_15
                                print(f"""
Along the way, they encountered a Brocolli Monster 🥦.
Nooooo (｡>﹏<)
It was throwing small brocolli to their car.
Their car was covered with pieces of brocolli 🥦🥦🥦! In which direction should they go to?")
\n""")
                                
                                question3_1_15choice = input("Left or Right? 🧠 ")

                                question3_1_15choice = question3_1_15choice.casefold()
                                
                                if 'left' in question3_1_15choice.lower().strip() or question3_1_15choice == 'l':
                                    print("💨 💨 💨")
                                    time.sleep(2)
                                    print(f"""
They have now escaped the Brocolli Monster 🥦.
Woooohh! That was scary. Thanks for helping.
\n""")
                                    time.sleep(3)
                                    print("YAAAAYYY! Joy and Sadness are now back to the Headquarters!")
                                
                                    win()
                                    
                                else:
                                    print("💨 💨 💨")
                                    time.sleep(1)
                                    print(f"""
🚨🚨🚨
Their car bumped into a big brocolli 🥦 and fell to the Memory Dump.
( ;´ - `;)
\n""")
                                   
                                    fail()
                           
                        else:
                            stage4()
     
    
                else:
                    print("Really? <( ⸝⸝•̀ - •́⸝⸝)> Please follow the instructions.")
                    stage3()

            else:
                print("Really? <( ⸝⸝•̀ - •́⸝⸝)> Please follow the instructions.")
                stage3()
            
        else:
            print("Really? <( ⸝⸝•̀ - •́⸝⸝)> Please follow the instructions.")
            stage3()
          
    else:
        print("Sorry, but Joy and Sadness got kicked out by the Cloud Monster.")
        
        fail()
        
        #used emoji text to show emotions (16)             
        
            
            

#WORKING 12/1 11:09 q2_1_5 
# 12/3 12:40 AM        
        
#here
# 12/3 3:58

def stage4():
    print(f"""
Another way to go back to the Headquarters is through riding the Train of Thought.

Train of Thought delivers daydreams, ideas, and other thoughts to the Headquarters
and transfer memories to other parts of Riley's mind.

Riley needs to be awake in order to keep the operation going.

Now that she's sleeping, they went to Dream Productions to wake her up.

What should Joy and Sadness do to wake her up?
a. In her dream, put a sad scene from a movie.
b. In her dream, put a scene where she's being chased by a big clown.

Enter the letter of your choice.
\n""")
    
    q4choice = input(prompt = "🧠 ")
    
#casefolding the input
    q4choice = q4choice.casefold()
    
    if 'sad' in q4choice.lower().strip() or q4choice.strip() == 'a'or 'movie' in q4choice.lower().strip():
        print("Bing Bong, Joy, and Sadness were arrested and put to Subconscious, where all her fears are stored.")
        print("Unfortunately, the clown woke up and chased them.")
        print(f"""
What should Joy and Sadness do to escape from the clown?")
a. Make Sadness cry to create a flood and washout the clown
b. Make them run as fast as they can.

Enter the letter of your choice.
\n""")

        q4_1choice = input(prompt = "🧠 ")
    
#casefolding the input
        q4_1choice = q4_1choice.casefold()
    
        if 'flood' in q4_1choice.lower().strip() or q4_1choice.strip() == 'a':
            print("💨 💨 💨")
            print("Joy and Sadness got a speed booster and reached outside the Headquarters! Yaaayyy!")
            
            stage2()
        
        elif 'run' in q4_1choice.lower().strip() or q4_1choice.strip() == 'b':
            print("Oh no! The clown has captured them and threw them to the Memory Dump.")
            
            fail()
        
        else:
            print("Really? <( ⸝⸝•̀ - •́⸝⸝)> Please follow the instructions.")
        
            stage4()
        
    elif 'clown' in q4choice.lower().strip() or q4choice.strip() == 'b'or 'chased' in q4choice.lower().strip():
            print("Riley woke up from a bad dream.")
            print("Joy, Sadness, and Bing Bong finally rode the Train of Thought")
            print(" ") #for space
            print(f"""
Meanwhile, Riley got up and decided to pack her things to move back to Minnesota. 


Back inside her head, all the remaining islands collapsed, which made the train fall to the Memory Dump.

Luckily they found the Wagon Rocket, which they can use to fly back to the Headquarters.

Help Joy, Sadness, and Bing Bong chant!

Chant:
Who's your friend who likes to play?
a. Wee Woo! Wee Woo!
b. Bing Bong! Bing Bong!
\n""")
            q4_2choice = input(prompt = "🧠 ")
    
        #casefolding the input
            q4_2choice = q4_2choice.casefold()
            
            if 'wee woo' in q4_2choice.lower().strip() or q4_2choice.strip() == 'a':
                print(f"""
Who's your friend who likes to play?
Wee Woo! Wee Woo!
\n""")
                print(f"""
His rocket makes you yell, 'Hooray!'
\n""")
                time.sleep(2)
                print("Wait. It's just going around the Memory Dump, not flying")
               
                fail()
            
            elif 'bing bong' in q4_2choice.lower().strip() or q4_2choice.strip() == 'b':
                print(f"""
Who's your friend who likes to play?
Bing Bong! Bing Bong!
\n""")
                print(f"""
His rocket makes you yell, 'Hooray!'
\n""")          
                print("""
Bing Bong! Bing Bong!
\n""")
                print("""
Who's the best in every way, and wants to sing this song to say
\n""")
                print("""
Bing Bong! Bing Bong!
\n""")
                time.sleep(2)
                
                print("We did it!")
                
                win()
            else:
                fail()
                
        
    else:
        print("Really? <( ⸝⸝•̀ - •́⸝⸝)> Please follow the instructions.")
        
        stage4()
    
    
    
    
    

        
       
        
# do not remove
insideout()

# 12/2 3:43 WORKING
# 12/3 2:36 done with the possible answers
# 12/3 3:51 getting there
# 12/3 6:30

# %% [markdown]
# Kimberly Batin
#
# Master of Business Analytics
#
# December 3, 2023
#
# Movie: Inside Out (2015)
#
#
#
# References:
#
# Docter, P. (Director). (2015). Inside Out [Film]. Pixar Animation Studios
#
# Emoji Combos. (n.d.). ASCII Art. Retrieved from https://emojicombos.com/ascii-art
#
# Kusterer, C. (n.d.). Special - Game Starter Code. Jupyter. http://localhost:8888/notebooks/Downloads/Special%20-%20Game%20Starter%20Code.ipynb
#
# Pixar Animation Studios. (n.d.). Inside Out. Retrieved from https://www.pixar.com/feature-films/inside-out
#
# TextEmoji. (n.d.). Retrieved from https://www.textemoji.org/
